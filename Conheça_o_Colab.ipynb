# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeEduardoGS/Cronicas-das-Almas/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("tidyverse")
install.packages("ggthemes")
install.packages("corrplot")
install.packages("GGally")
install.packages("DT")
install.packages("caret")

# %%
library(tidyverse)
library(ggthemes)
library(corrplot)
library(GGally)
library(DT)
library(caret)

# %%
loan=read.csv("/content/loan.csv",na =" ")

View(loan)

colnames(loan)
# Out:
#     Loan_ID  Gender Married Dependents Education    Self_Employed
# 1   LP001002 Male   No      0          Graduate     No
# 2   LP001003 Male   Yes     1          Graduate     No
# 3   LP001005 Male   Yes     0          Graduate     Yes
# 4   LP001006 Male   Yes     0          Not Graduate No
# 5   LP001008 Male   No      0          Graduate     No
# 6   LP001011 Male   Yes     2          Graduate     Yes
# 7   LP001013 Male   Yes     0          Not Graduate No
# 8   LP001014 Male   Yes     3+         Graduate     No
# 9   LP001018 Male   Yes     2          Graduate     No
# 10  LP001020 Male   Yes     1          Graduate     No
# 11  LP001024 Male   Yes     2          Graduate     No
# 12  LP001027 Male   Yes     2          Graduate
# 13  LP001028 Male   Yes     2          Graduate     No
# 14  LP001029 Male   No      0          Graduate     No
# 15  LP001030 Male   Yes     2          Graduate     No
# 16  LP001032 Male   No      0          Graduate     No
# ...

# %%
loanteste1 = loan%>%
  select(Loan_Status, LoanAmount, Credit_History, Gender, ApplicantIncome, Loan_Amount_Term)

loanteste1
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 1   Y            NA         1             Male    5849
# 2   N           128         1             Male    4583
# 3   Y            66         1             Male    3000
# 4   Y           120         1             Male    2583
# 5   Y           141         1             Male    6000
# 6   Y           267         1             Male    5417
# 7   Y            95         1             Male    2333
# 8   N           158         0             Male    3036
# 9   Y           168         1             Male    4006
# 10  N           349         1             Male   12841
# 11  Y            70         1             Male    3200
# 12  Y           109         1             Male    2500
# 13  Y           200         1             Male    3073
# 14  N           114         1             Male    1853
# 15  Y            17         1             Male    1299
# 16  Y           125         1             Male    4950
# ...

# %%
sapply(loanteste1, function(x) sum(is.na(x)))
# Out:
#      Loan_Status       LoanAmount   Credit_History           Gender
#                0               22               50                0
#  ApplicantIncome Loan_Amount_Term
#                0               14

# %%
loanteste2 = loanteste1 %>%
  filter(!is.na(Loan_Amount_Term), !is.na(LoanAmount), !is.na(Credit_History))

loanteste2
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 1   N           128        1              Male    4583
# 2   Y            66        1              Male    3000
# 3   Y           120        1              Male    2583
# 4   Y           141        1              Male    6000
# 5   Y           267        1              Male    5417
# 6   Y            95        1              Male    2333
# 7   N           158        0              Male    3036
# 8   Y           168        1              Male    4006
# 9   N           349        1              Male   12841
# 10  Y            70        1              Male    3200
# 11  Y           109        1              Male    2500
# 12  Y           200        1              Male    3073
# 13  N           114        1              Male    1853
# 14  Y            17        1              Male    1299
# 15  Y           125        1              Male    4950
# 16  N            76        0              Female  3510
# ...

# %%
loan1 <- na.omit(loan)
loan1
# Out:
#     Loan_ID  Gender Married Dependents Education    Self_Employed
# 2   LP001003 Male   Yes     1          Graduate     No
# 3   LP001005 Male   Yes     0          Graduate     Yes
# 4   LP001006 Male   Yes     0          Not Graduate No
# 5   LP001008 Male   No      0          Graduate     No
# 6   LP001011 Male   Yes     2          Graduate     Yes
# 7   LP001013 Male   Yes     0          Not Graduate No
# 8   LP001014 Male   Yes     3+         Graduate     No
# 9   LP001018 Male   Yes     2          Graduate     No
# 10  LP001020 Male   Yes     1          Graduate     No
# 11  LP001024 Male   Yes     2          Graduate     No
# 12  LP001027 Male   Yes     2          Graduate
# 13  LP001028 Male   Yes     2          Graduate     No
# 14  LP001029 Male   No      0          Graduate     No
# 15  LP001030 Male   Yes     2          Graduate     No
# 16  LP001032 Male   No      0          Graduate     No
# 18  LP001036 Female No      0          Graduate     No
# ...

# %%
sapply(loan1, function(x) sum(is.na(x)))
# Out:
#           Loan_ID            Gender           Married        Dependents
#                 0                 0                 0                 0
#         Education     Self_Employed   ApplicantIncome CoapplicantIncome
#                 0                 0                 0                 0
#        LoanAmount  Loan_Amount_Term    Credit_History     Property_Area
#                 0                 0                 0                 0
#       Loan_Status
#                 0

# %%
loanteste2 %>%
  count(Loan_Status) %>%
  ggplot(aes(x = reorder(Loan_Status, desc(n)), y = n, fill = n)) +
  geom_col() +
  coord_flip() +
  labs(x = "Status Empréstimo", y = "Count")
# Out:
# plot without title

# %%
ggplot(loan, aes(x = Education, y = ApplicantIncome, fill = Education)) +
  geom_boxplot() +
  theme_gray() +
  labs(y="Renda Requerente", x= "Graduação")
# Out:
# plot without title

# %%
loanteste3 = loan %>%
  select(Loan_Status, LoanAmount,Credit_History,
Gender, ApplicantIncome,Loan_Amount_Term, Education)

loanteste3
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 1   Y            NA         1             Male    5849
# 2   N           128         1             Male    4583
# 3   Y            66         1             Male    3000
# 4   Y           120         1             Male    2583
# 5   Y           141         1             Male    6000
# 6   Y           267         1             Male    5417
# 7   Y            95         1             Male    2333
# 8   N           158         0             Male    3036
# 9   Y           168         1             Male    4006
# 10  N           349         1             Male   12841
# 11  Y            70         1             Male    3200
# 12  Y           109         1             Male    2500
# 13  Y           200         1             Male    3073
# 14  N           114         1             Male    1853
# 15  Y            17         1             Male    1299
# 16  Y           125         1             Male    4950
# ...

# %%
loansubset1<-na.omit(loanteste3)

loansubset1
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 2   N           128        1              Male    4583
# 3   Y            66        1              Male    3000
# 4   Y           120        1              Male    2583
# 5   Y           141        1              Male    6000
# 6   Y           267        1              Male    5417
# 7   Y            95        1              Male    2333
# 8   N           158        0              Male    3036
# 9   Y           168        1              Male    4006
# 10  N           349        1              Male   12841
# 11  Y            70        1              Male    3200
# 12  Y           109        1              Male    2500
# 13  Y           200        1              Male    3073
# 14  N           114        1              Male    1853
# 15  Y            17        1              Male    1299
# 16  Y           125        1              Male    4950
# 18  N            76        0              Female  3510
# ...

# %%
summary(loansubset1)
# Out:
#  Loan_Status          LoanAmount    Credit_History      Gender
#  Length:529         Min.   :  9.0   Min.   :0.0000   Length:529
#  Class :character   1st Qu.:100.0   1st Qu.:1.0000   Class :character
#  Mode  :character   Median :128.0   Median :1.0000   Mode  :character
#                     Mean   :145.9   Mean   :0.8507
#                     3rd Qu.:167.0   3rd Qu.:1.0000
#                     Max.   :700.0   Max.   :1.0000
#  ApplicantIncome Loan_Amount_Term  Education
#  Min.   :  150   Min.   : 36.0    Length:529
#  1st Qu.: 2900   1st Qu.:360.0    Class :character
#  Median : 3816   Median :360.0    Mode  :character
#  Mean   : 5508   Mean   :342.4
#  3rd Qu.: 5815   3rd Qu.:360.0
#  Max.   :81000   Max.   :480.0

# %%
loansubset2<-loansubset1[loansubset1$ApplicantIncome>80000,]
loansubset2
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 410 N           360        0              Male   81000
#     Loan_Amount_Term Education
# 410 360              Graduate

# %%
summary(loansubset1)
# Out:
#  Loan_Status          LoanAmount    Credit_History      Gender
#  Length:529         Min.   :  9.0   Min.   :0.0000   Length:529
#  Class :character   1st Qu.:100.0   1st Qu.:1.0000   Class :character
#  Mode  :character   Median :128.0   Median :1.0000   Mode  :character
#                     Mean   :145.9   Mean   :0.8507
#                     3rd Qu.:167.0   3rd Qu.:1.0000
#                     Max.   :700.0   Max.   :1.0000
#  ApplicantIncome Loan_Amount_Term  Education
#  Min.   :  150   Min.   : 36.0    Length:529
#  1st Qu.: 2900   1st Qu.:360.0    Class :character
#  Median : 3816   Median :360.0    Mode  :character
#  Mean   : 5508   Mean   :342.4
#  3rd Qu.: 5815   3rd Qu.:360.0
#  Max.   :81000   Max.   :480.0

# %%
loansubset1$id<-c(1:529)
loansubset1
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 2   N           128        1              Male    4583
# 3   Y            66        1              Male    3000
# 4   Y           120        1              Male    2583
# 5   Y           141        1              Male    6000
# 6   Y           267        1              Male    5417
# 7   Y            95        1              Male    2333
# 8   N           158        0              Male    3036
# 9   Y           168        1              Male    4006
# 10  N           349        1              Male   12841
# 11  Y            70        1              Male    3200
# 12  Y           109        1              Male    2500
# 13  Y           200        1              Male    3073
# 14  N           114        1              Male    1853
# 15  Y            17        1              Male    1299
# 16  Y           125        1              Male    4950
# 18  N            76        0              Female  3510
# ...

# %%
loansubset2<-loansubset1[loansubset1$ApplicantIncome>80000,]
loansubset2
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 410 N           360        0              Male   81000
#     Loan_Amount_Term Education id
# 410 360              Graduate  352

# %%
loanremove<-loansubset1[-352,]
summary(loanremove)
# Out:
#  Loan_Status          LoanAmount    Credit_History      Gender
#  Length:528         Min.   :  9.0   Min.   :0.0000   Length:528
#  Class :character   1st Qu.:100.0   1st Qu.:1.0000   Class :character
#  Mode  :character   Median :128.0   Median :1.0000   Mode  :character
#                     Mean   :145.4   Mean   :0.8523
#                     3rd Qu.:166.2   3rd Qu.:1.0000
#                     Max.   :700.0   Max.   :1.0000
#  ApplicantIncome Loan_Amount_Term  Education               id
#  Min.   :  150   Min.   : 36.0    Length:528         Min.   :  1.0
#  1st Qu.: 2899   1st Qu.:360.0    Class :character   1st Qu.:132.8
#  Median : 3815   Median :360.0    Mode  :character   Median :264.5
#  Mean   : 5365   Mean   :342.3                       Mean   :264.8
#  3rd Qu.: 5804   3rd Qu.:360.0                       3rd Qu.:397.2
#  Max.   :63337   Max.   :480.0                       Max.   :529.0

# %%
ggplot(loanremove, aes(x = Education, y = ApplicantIncome, fill = Education)) +
  geom_boxplot() +
  theme_gray() +
  labs(y="Renda Requerente", x= "Graduação")
# Out:
# plot without title

# %%
loansubset2<-loansubset1[loansubset1$ApplicantIncome>40000,]
loansubset2
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 172 Y           700        1                     51763
# 334 Y           490        1              Male   63337
# 410 N           360        0              Male   81000
#     Loan_Amount_Term Education id
# 172 300              Graduate  144
# 334 180              Graduate  285
# 410 360              Graduate  352

# %%
loanremove1<-loansubset1[-352,]
loanremove2<-loanremove1[-285,]
loanremove3<-loanremove2[-144,]
loanremove3
# Out:
#     Loan_Status LoanAmount Credit_History Gender ApplicantIncome
# 2   N           128        1              Male    4583
# 3   Y            66        1              Male    3000
# 4   Y           120        1              Male    2583
# 5   Y           141        1              Male    6000
# 6   Y           267        1              Male    5417
# 7   Y            95        1              Male    2333
# 8   N           158        0              Male    3036
# 9   Y           168        1              Male    4006
# 10  N           349        1              Male   12841
# 11  Y            70        1              Male    3200
# 12  Y           109        1              Male    2500
# 13  Y           200        1              Male    3073
# 14  N           114        1              Male    1853
# 15  Y            17        1              Male    1299
# 16  Y           125        1              Male    4950
# 18  N            76        0              Female  3510
# ...

# %%
summary(loanremove3)
# Out:
#  Loan_Status          LoanAmount    Credit_History      Gender
#  Length:526         Min.   :  9.0   Min.   :0.0000   Length:526
#  Class :character   1st Qu.:100.0   1st Qu.:1.0000   Class :character
#  Mode  :character   Median :128.0   Median :1.0000   Mode  :character
#                     Mean   :143.7   Mean   :0.8517
#                     3rd Qu.:165.0   3rd Qu.:1.0000
#                     Max.   :600.0   Max.   :1.0000
#  ApplicantIncome Loan_Amount_Term  Education               id
#  Min.   :  150   Min.   : 36.0    Length:526         Min.   :  1.0
#  1st Qu.: 2896   1st Qu.:360.0    Class :character   1st Qu.:132.2
#  Median : 3814   Median :360.0    Mode  :character   Median :264.5
#  Mean   : 5166   Mean   :342.7                       Mean   :265.0
#  3rd Qu.: 5766   3rd Qu.:360.0                       3rd Qu.:397.8
#  Max.   :39999   Max.   :480.0                       Max.   :529.0

# %%
ggplot(loanremove3, aes(x = Education, y = ApplicantIncome, fill = Education)) +
  geom_boxplot() +
  theme_gray() +
  labs(y="Renda Requerente", x= "Graduação")
# Out:
# plot without title

# %%
loanFiltrado <- loan

# %%
loanFiltrado <- loanFiltrado[loanFiltrado$ApplicantIncome < 8000, ]

# %%
ggplot(loanFiltrado, aes(x = Education, y = ApplicantIncome, fill = Education)) +
  geom_boxplot() +
  theme_gray() +
  labs(y="Renda Requerente", x= "Graduação")
# Out:
# plot without title

# %%
install.packages("Amelia")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘RcppArmadillo’

# %%
install.packages("Rcpp")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(Amelia)

# %%
missmap(loanremove3,main = "valores ausentes")
# Out:
# Plot with title “valores ausentes”

# %%
glm(loanremove3$Credit_History ~loanremove3$Gender, family = binomial(link = logit))
# Out:
# Call:  glm(formula = loanremove3$Credit_History ~ loanremove3$Gender,
#     family = binomial(link = logit))
#
# Coefficients:
#              (Intercept)  loanremove3$GenderFemale    loanremove3$GenderMale
#                   0.9808                    0.6931                    0.8109
#
# Degrees of Freedom: 525 Total (i.e. Null);  523 Residual
# Null Deviance:	    441.6
# Residual Deviance: 440.3 	AIC: 446.3

# %%
glm(loanremove3$Credit_History ~loanremove3$Gender + loanremove3$Education, family = binomial(link = logit))
# Out:
# Call:  glm(formula = loanremove3$Credit_History ~ loanremove3$Gender +
#     loanremove3$Education, family = binomial(link = logit))
#
# Coefficients:
#                       (Intercept)           loanremove3$GenderFemale
#                            1.0253                             0.7292
#            loanremove3$GenderMale  loanremove3$EducationNot Graduate
#                            0.8778                            -0.4501
#
# Degrees of Freedom: 525 Total (i.e. Null);  522 Residual
# Null Deviance:	    441.6
# Residual Deviance: 437.9 	AIC: 445.9

# %%
glm(loanremove3$Credit_History ~loanremove3$Gender + loanremove3$Education +
loanremove3$ApplicantIncome, family = binomial(link = logit))
# Out:
# Call:  glm(formula = loanremove3$Credit_History ~ loanremove3$Gender +
#     loanremove3$Education + loanremove3$ApplicantIncome, family = binomial(link = logit))
#
# Coefficients:
#                       (Intercept)           loanremove3$GenderFemale
#                         9.348e-01                          7.563e-01
#            loanremove3$GenderMale  loanremove3$EducationNot Graduate
#                         9.009e-01                         -4.307e-01
#       loanremove3$ApplicantIncome
#                         1.242e-05
#
# Degrees of Freedom: 525 Total (i.e. Null);  521 Residual
# Null Deviance:	    441.6
# Residual Deviance: 437.7 	AIC: 447.7
